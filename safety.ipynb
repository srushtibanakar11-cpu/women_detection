# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %%
df= pd.read_csv(r'D:\women_detection\womens_safety_filtered_data.csv')

# %%
df
# Out:
#          Latitude  Longitude                CrimeGroup_Name  FIR_MONTH  \
# 0             NaN        NaN                          POCSO          1
# 1             NaN        NaN  MOTOR VEHICLE ACCIDENTS FATAL          1
# 2             NaN        NaN             CRUELTY BY HUSBAND          1
# 3             NaN        NaN  MOTOR VEHICLE ACCIDENTS FATAL          2
# 4             NaN        NaN  MOTOR VEHICLE ACCIDENTS FATAL          2
# ...           ...        ...                            ...        ...
# 380834  16.748633  77.133669                 MISSING PERSON          1
# 380835  16.844536  77.021722                          POCSO          1
# 380836  16.556974  77.159238                    MOLESTATION          2
# 380837  16.772232  77.117018        CRIMES RELATED TO WOMEN          2
# 380838  16.800526  77.141569       KIDNAPPING AND ABDUCTION          2
#
#         FIR_Day District_Name          UnitName  Female  Girl
# ...

# %%
df.head()
# Out:
#    Latitude  Longitude                CrimeGroup_Name  FIR_MONTH  FIR_Day  \
# 0       NaN        NaN                          POCSO          1        5
# 1       NaN        NaN  MOTOR VEHICLE ACCIDENTS FATAL          1       18
# 2       NaN        NaN             CRUELTY BY HUSBAND          1       31
# 3       NaN        NaN  MOTOR VEHICLE ACCIDENTS FATAL          2       10
# 4       NaN        NaN  MOTOR VEHICLE ACCIDENTS FATAL          2       15
#
#   District_Name    UnitName  Female  Girl
# 0      Bagalkot  Amengad PS       0     1
# 1      Bagalkot  Amengad PS       1     0
# 2      Bagalkot  Amengad PS       1     0
# 3      Bagalkot  Amengad PS       1     0
# 4      Bagalkot  Amengad PS       1     0
